# %% [markdown]
# # scVI Tutorial
#
# This tutorial covers basic scVI usage.

# %%
import scvi

scvi.model.SCVI.setup_anndata(adata)
# Out:
# Training...

# %%
model = scvi.model.SCVI(adata)
model.train()
